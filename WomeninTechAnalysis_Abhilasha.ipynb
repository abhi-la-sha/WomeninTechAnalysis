# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi-la-sha/WomeninTechAnalysis/blob/main/WomeninTechAnalysis_Abhilasha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot

# %%
file0 = pd.read_csv("Country-Code-Mapping.csv")
file0
# Out:
#      Value           Label
# 0        4     Afghanistan
# 1        6         Albania
# 2        7         Algeria
# 3        8  American Samoa
# 4        9         Andorra
# ..     ...             ...
# 147    171      Uzbekistan
# 148    172       Venezuela
# 149    173         Vietnam
# 150    174           Yemen
# 151    175        Zimbabwe
#
# [152 rows x 2 columns]

# %%
file0.describe()
# Out:
#             Value
# count  152.000000
# mean    88.605263
# std     50.131504
# min      4.000000
# 25%     44.750000
# 50%     87.500000
# 75%    132.500000
# max    175.000000

# %%
file0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   152 non-null    int64
#  1   Label   152 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.5+ KB

# %%
file1 = pd.read_csv("Codebook.csv")
file1.head(10)
# Out:
#          Data Field                                    Survey Question  \
# 0      RespondentID                                                NaN
# 1         StartDate                                                NaN
# 2           EndDate                                                NaN
# 3   CountryNumeric2                                                NaN
# 4  q1AgeBeginCoding                   At what age did you start coding
# 5             q2Age                               How old are you now?
# 6          q3Gender                  What gender do you identify with?
# 7       q4Education  What is the highest level of education you hav...
# 8       q0004_other                             Other (please specify)
# 9     q5DegreeFocus             What is the focus area of your degree?
#
#                                              Notes
# 0                                    Respondent ID
# 1              When did they start (date and time)
# ...

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data Field       251 non-null    object
#  1   Survey Question  247 non-null    object
#  2   Notes            100 non-null    object
# dtypes: object(3)
# memory usage: 6.0+ KB

# %%
file1["Survey Question"][(file1["Data Field"] == "q1AgeBeginCoding")]
# Out:
# 4    At what age did you start coding
# Name: Survey Question, dtype: object

# %%
file2 = pd.read_csv("Numeric-Mapping.csv")
file2.head(10)
# Out:
#          Data Field  Value               Label
# 0  q1AgeBeginCoding      1    5 - 10 years old
# 1  q1AgeBeginCoding      2   11 - 15 years old
# 2  q1AgeBeginCoding      3   16 - 20 years old
# 3  q1AgeBeginCoding      4   21 - 25 years old
# 4  q1AgeBeginCoding      5   26 - 30 years old
# 5  q1AgeBeginCoding      6   31 - 35 years old
# 6  q1AgeBeginCoding      7   36 - 40 years old
# 7  q1AgeBeginCoding      8   41 - 50 years old
# 8  q1AgeBeginCoding      9  50+ years or older
# 9             q2Age      1  Under 12 years old

# %%
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data Field  452 non-null    object
#  1   Value       452 non-null    int64
#  2   Label       451 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 10.7+ KB

# %%
file3 = pd.read_csv("Numeric.csv")
file3.head(10)
# Out:
# <ipython-input-13-284c6ad9c2b9>:1: DtypeWarning: Columns (10,19,137,138,250) have mixed types. Specify dtype option on import or set low_memory=False.
#   file3 = pd.read_csv("Numeric.csv")
#    RespondentID       StartDate         EndDate  CountryNumeric2  \
# 0    6464453728  10/19/17 11:51  10/20/17 12:05            148.0
# 1    6478031510   10/26/17 6:18   10/26/17 7:49            164.0
# 2    6464392829  10/19/17 10:44  10/19/17 10:56             98.0
# 3    6481629912   10/27/17 1:51   10/27/17 2:05             43.0
# 4    6488385057  10/31/17 11:46  10/31/17 11:59              NaN
# 5    6463843138   10/19/17 3:02   10/19/17 3:18            167.0
# 6    6458326054   10/17/17 3:18   10/17/17 3:33            167.0
# 7    6467198274   10/21/17 8:55   10/21/17 9:06            167.0
# 8    6477950548   10/26/17 7:03   10/26/17 7:12            154.0
# 9    6477542461   10/26/17 4:23   10/26/17 4:30             78.0
#
# ...

# %%
file4 = pd.read_csv("Values.csv")
file4.head(10)
# Out:
# <ipython-input-14-e6b0d2bfe07d>:1: DtypeWarning: Columns (3,10,19,137,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   file4 = pd.read_csv("Values.csv")
#    RespondentID       StartDate         EndDate CountryNumeric2  \
# 0    6464453728  10/19/17 11:51  10/20/17 12:05     South Korea
# 1    6478031510   10/26/17 6:18   10/26/17 7:49         Ukraine
# 2    6464392829  10/19/17 10:44  10/19/17 10:56        Malaysia
# 3    6481629912   10/27/17 1:51   10/27/17 2:05         Curaçao
# 4    6488385057  10/31/17 11:46  10/31/17 11:59             NaN
# 5    6463843138   10/19/17 3:02   10/19/17 3:18   United States
# 6    6458326054   10/17/17 3:18   10/17/17 3:33   United States
# 7    6467198274   10/21/17 8:55   10/21/17 9:06   United States
# 8    6477950548   10/26/17 7:03   10/26/17 7:12     Switzerland
# 9    6477542461   10/26/17 4:23   10/26/17 4:30          Israel
#
#     q1AgeBeginCoding              q2Age q3Gender  \
# ...

# %%
file4.drop('q32RecommendHackerRank', inplace=True, axis=1)

# %%
file4.head(10)
# Out:
#    RespondentID       StartDate         EndDate CountryNumeric2  \
# 0    6464453728  10/19/17 11:51  10/20/17 12:05     South Korea
# 1    6478031510   10/26/17 6:18   10/26/17 7:49         Ukraine
# 2    6464392829  10/19/17 10:44  10/19/17 10:56        Malaysia
# 3    6481629912   10/27/17 1:51   10/27/17 2:05         Curaçao
# 4    6488385057  10/31/17 11:46  10/31/17 11:59             NaN
# 5    6463843138   10/19/17 3:02   10/19/17 3:18   United States
# 6    6458326054   10/17/17 3:18   10/17/17 3:33   United States
# 7    6467198274   10/21/17 8:55   10/21/17 9:06   United States
# 8    6477950548   10/26/17 7:03   10/26/17 7:12     Switzerland
# 9    6477542461   10/26/17 4:23   10/26/17 4:30          Israel
#
#     q1AgeBeginCoding              q2Age q3Gender  \
# 0  16 - 20 years old  18 - 24 years old   Female
# 1  16 - 20 years old  25 - 34 years old     Male
# 2  11 - 15 years old  12 - 18 years old   Female
# 3  11 - 15 years old  12 - 18 years old     Male
# ...

# %%
file4.drop('q33HackerRankChallforJob', inplace=True, axis=1)
file4.drop('q34IdealLengHackerRankTest', inplace=True, axis=1)
file4.drop('q34PositiveExp', inplace=True, axis=1)
file4.head(10)
# Out:
#    RespondentID       StartDate         EndDate CountryNumeric2  \
# 0    6464453728  10/19/17 11:51  10/20/17 12:05     South Korea
# 1    6478031510   10/26/17 6:18   10/26/17 7:49         Ukraine
# 2    6464392829  10/19/17 10:44  10/19/17 10:56        Malaysia
# 3    6481629912   10/27/17 1:51   10/27/17 2:05         Curaçao
# 4    6488385057  10/31/17 11:46  10/31/17 11:59             NaN
# 5    6463843138   10/19/17 3:02   10/19/17 3:18   United States
# 6    6458326054   10/17/17 3:18   10/17/17 3:33   United States
# 7    6467198274   10/21/17 8:55   10/21/17 9:06   United States
# 8    6477950548   10/26/17 7:03   10/26/17 7:12     Switzerland
# 9    6477542461   10/26/17 4:23   10/26/17 4:30          Israel
#
#     q1AgeBeginCoding              q2Age q3Gender  \
# 0  16 - 20 years old  18 - 24 years old   Female
# 1  16 - 20 years old  25 - 34 years old     Male
# 2  11 - 15 years old  12 - 18 years old   Female
# 3  11 - 15 years old  12 - 18 years old     Male
# ...

# %%
file3_male = file3[(file3["q3Gender"] == '1')]
file3_female = file3[(file3["q3Gender"] == '2')]
file4_male = file4[(file4["q3Gender"] == 'Male')]
file4_female = file4[(file4["q3Gender"] == 'Female')]

# %%
file4["q3Gender"].value_counts()
# Out:
# q3Gender
# Male          20774
# Female         4122
# Non-Binary      125
# #NULL!           69
# Name: count, dtype: int64

# %%
male = file4["q3Gender"][(file4["q3Gender"] == 'Male')].count()
female = file4["q3Gender"][(file4["q3Gender"] == 'Female')].count()
percent_womenintech = (female/(male + female))*100
print('Count of men vs women:',male,":",female)
print('percentage of women in tech:', percent_womenintech)
# Out:
# Count of men vs women: 20774 : 4122
# percentage of women in tech: 16.556876606683804

# %%
def verify_missing_fields(female_values, male_values, female_index, male_index):

    fields_in_m = np.setdiff1d(male_index, female_index)
    female_index = list(female_index)
    female_values = list(female_values)
    for i in fields_in_m:
        female_index.append(i)
        female_values.append(0)

    fields_in_f = np.setdiff1d(female_index, male_index)
    male_index = list(male_index)
    male_values = list(male_values)
    for j in fields_in_f:
        male_index.append(j)
        male_values.append(0)

    return female_values, male_values, female_index, male_index

# %%
def age(fname):

    age1 = fname["q2Age"][(fname["q2Age"] != '#NULL!')].value_counts()
    age = age1.to_numpy()
    age_index = age1.index.to_numpy()

    return age, age_index

age_m, age_index_m = age(file4_male)
age_f, age_index_f = age(file4_female)

age_f, age_m, age_index_f, age_index_m= verify_missing_fields(age_f, age_m, age_index_f, age_index_m)

df_plot = pd.DataFrame({'age_male': age_m,
                   'age_female': age_f}, index=age_index_f)

graph = df_plot.plot.bar(rot=90)

# %%
def stats(value_m, value_f):

    percent_f = [(value_f[i]/(value_f[i]+val))*100
    for i, val in enumerate(value_m)]
    return percent_f

# %%
percent_f = stats(age_m, age_f)

df = pd.DataFrame({'percentage of women': percent_f}, index=age_index_f)
graph1 = df.plot.bar(rot=90)

# %%
female_industry_count = file4[(file4['q3Gender'] == 'Female') & (file4['q10Industry'] != '#NULL!')]['q10Industry'].value_counts()
print(female_industry_count)
# Out:
# q10Industry
# Technology                        1708
# Education                          651
# Financial Services                 235
# Media                              111
# Computer Hardware                   93
# Retail                              93
# Health Care                         89
# Automotive & Transportation         79
# Government                          63
# Security                            62
# Aerospace & Defense                 58
# Non-Profit                          41
# Insurance                           25
# Telecom, Internet Services          22
# Food & Beverage                     20
# Professional Services               15
# Travel, Tourism, Accommodation      13
# Energy, Oil, Gas, Utilities         12
# Real estate                          6
# Name: count, dtype: int64

# %%
female_industry_count.plot(kind='bar', rot=90)
plot.show()

# %%
tech_data = file4[(file4['q10Industry'] == 'Technology')]

male_count = tech_data[tech_data['q3Gender'] == 'Male']['q3Gender'].count()
female_count = tech_data[tech_data['q3Gender'] == 'Female']['q3Gender'].count()

data = {'Gender': ['Male', 'Female'], 'Count': [male_count, female_count]}
df_plot = pd.DataFrame(data)

df_plot.plot(kind='bar', x='Gender', y='Count', rot=0)
plot.show()

# %%
role_count = file4.groupby(['q9CurrentRole', 'q3Gender'])['q3Gender'].count().unstack()

role_count.plot(kind='bar', rot=90, width=1)
plot.show()
